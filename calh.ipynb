# %%
# %matplotlib widget
from calh.app import App
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
app = App()
app.create()
# Out:
# Card(children=[ProgressLinear(indeterminate=False), Toolbar(children=[Btn(children=[FileUpload(value={}, descr…
# ...
